# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/keystrokes/processed/keystroke_features_clean.csv")
df.head()
# Out:
#        mean        std     max  non_zero_fraction  percentile_75  user_id
# 0  3.976298  19.272551  121.71           0.866337            0.0        1
# 1  3.541526  18.788000  121.71           0.865099            0.0        1
# 2  3.106754  17.049511  121.71           0.865099            0.0        1
# 3  2.671982  16.476673  121.71           0.863861            0.0        1
# 4  3.238798  16.522710  120.56           0.866337            0.0        1

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14850 entries, 0 to 14849
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mean               14850 non-null  float64
#  1   std                14850 non-null  float64
#  2   max                14850 non-null  float64
#  3   non_zero_fraction  14850 non-null  float64
#  4   percentile_75      14850 non-null  float64
#  5   user_id            14850 non-null  int64
# dtypes: float64(5), int64(1)
# memory usage: 696.2 KB
# (14850, 6)

# %%
df.hist(figsize=(15,10), bins=30)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
