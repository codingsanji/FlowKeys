# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../data/keystrokes/raw/free-text.csv")
df.head()
# Out:
# C:\Users\SombatlaTrucDeydeepy\AppData\Local\Temp\ipykernel_32336\391620006.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/keystrokes/raw/free-text.csv")
#   participant  session   key1   key2 DU.key1.key1  DD.key1.key2  DU.key1.key2  \
# 0        p001        1      W  Shift         0.15        -0.796         0.166
# 1        p001        1  Shift      e        0.962         1.148         1.255
# 2        p001        1      e  Space        0.107         0.172         0.252
# 3        p001        1  Space      b         0.08         0.200         0.280
# 4        p001        1      b      e         0.08         0.320         0.480
#
#    UD.key1.key2  UU.key1.key2   Unnamed: 9
# 0        -0.946          0.016         NaN
# 1         0.186          0.293         NaN
# 2         0.065          0.145         NaN
# 3         0.120          0.200         NaN
# 4         0.240          0.400         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562583 entries, 0 to 562582
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   participant    562583 non-null  object
#  1   session        562583 non-null  int64
#  2   key1           562583 non-null  object
#  3   key2           562385 non-null  object
#  4   DU.key1.key1   562583 non-null  object
#  5   DD.key1.key2   562385 non-null  float64
#  6   DU.key1.key2   562385 non-null  float64
#  7   UD.key1.key2   562385 non-null  float64
#  8   UU.key1.key2   562385 non-null  float64
#  9   Unnamed: 9     13 non-null      float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 42.9+ MB

# %%
df.isnull().sum()
# Out:
# participant           0
# session               0
# key1                  0
# key2                198
# DU.key1.key1          0
# DD.key1.key2        198
# DU.key1.key2        198
# UD.key1.key2        198
# UU.key1.key2        198
# Unnamed: 9       562570
# dtype: int64

# %%
df["Unnamed: 9"].isnull().sum()
# Out:
# np.int64(562570)

# %%
df[df['Unnamed: 9'].notnull()]
# Out:
#        participant  session       key1  \
# 23481         p005        1          2
# 169381        p031        1  Backspace
# 177980        p033        1          e
# 181842        p033        2          t
# 204716        p037        2  Backspace
# 205245        p037        2  Backspace
# 306776        p055        1  Backspace
# 319078        p057        1          y
# 491603        p087        1  Backspace
# 491610        p087        1      Shift
# 491613        p087        1  Backspace
# 552060        p099        1      Shift
# 552098        p099        1      Shift
#
#                                               key2 DU.key1.key1  DD.key1.key2  \
# 23481   ,0.087,1.088,1.183,1.001,1.096,\r\np005,1,        Shift         0.095
# 169381   ,0.081,0.761,0.896,0.68,0.815,\r\np031,1,        Shift         0.135
# 177980      ,0.088,0.2,0.28,0.112,0.192\r\np033,1,    Backspace         0.080
# 181842  ,0.079,0.184,0.263,0.105,0.184,\r\np033,2,        Shift         0.079
# ...

# %%
print(f"Original number of rows: {len(df)}")
df = df[df['Unnamed: 9'].isnull()]
print(f"Number of rows with nulls in 'Unnamed: 9': {len(df)}")
# Out:
# Original number of rows: 562583
# Number of rows with nulls in 'Unnamed: 9': 562570

# %%
df.dropna(subset=["Unnamed: 9"])
# Out:
# Empty DataFrame
# Columns: [participant, session, key1, key2, DU.key1.key1, DD.key1.key2, DU.key1.key2, UD.key1.key2, UU.key1.key2 , Unnamed: 9]
# Index: []

# %%
df.drop(columns=["Unnamed: 9"], inplace=True)

# %%
df.head()
# Out:
#   participant  session   key1   key2 DU.key1.key1  DD.key1.key2  DU.key1.key2  \
# 0        p001        1      W  Shift         0.15        -0.796         0.166
# 1        p001        1  Shift      e        0.962         1.148         1.255
# 2        p001        1      e  Space        0.107         0.172         0.252
# 3        p001        1  Space      b         0.08         0.200         0.280
# 4        p001        1      b      e         0.08         0.320         0.480
#
#    UD.key1.key2  UU.key1.key2
# 0        -0.946          0.016
# 1         0.186          0.293
# 2         0.065          0.145
# 3         0.120          0.200
# 4         0.240          0.400

# %%
df[23477:23486]
# Out:
#       participant  session       key1       key2 DU.key1.key1  DD.key1.key2  \
# 23477        p005        1          c          h        0.136         0.417
# 23478        p005        1          h          -        0.103         0.608
# 23479        p005        1          -          2        0.103         1.000
# 23480        p005        1          2          2        0.103         0.192
# 23482        p005        1      Shift  Backspace        0.752         1.208
# 23483        p005        1  Backspace          :        0.064         0.336
# 23484        p005        1          :      Shift        0.072        -0.224
# 23485        p005        1      Shift      Space         0.44         0.800
# 23486        p005        1      Space          a         0.16         0.296
#
#        DU.key1.key2  UD.key1.key2  UU.key1.key2
# 23477         0.520         0.281          0.384
# 23478         0.711         0.505          0.608
# 23479         1.103         0.897          1.000
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562570 entries, 0 to 562569
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   participant    562570 non-null  object
#  1   session        562570 non-null  int64
#  2   key1           562570 non-null  object
#  3   key2           562372 non-null  object
#  4   DU.key1.key1   562570 non-null  object
#  5   DD.key1.key2   562372 non-null  float64
#  6   DU.key1.key2   562372 non-null  float64
#  7   UD.key1.key2   562372 non-null  float64
#  8   UU.key1.key2   562372 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 38.6+ MB

# %%
df.isnull().sum()
# Out:
# participant        0
# session            0
# key1               0
# key2             198
# DU.key1.key1       0
# DD.key1.key2     198
# DU.key1.key2     198
# UD.key1.key2     198
# UU.key1.key2     198
# dtype: int64

# %%
df[df['key2'].isnull()]
# Out:
#        participant  session       key1 key2 DU.key1.key1  DD.key1.key2  \
# 2513          p001        1          e  NaN        0.136           NaN
# 5257          p001        2          s  NaN        0.143           NaN
# 7959          p002        1          e  NaN          0.1           NaN
# 10774         p002        2          s  NaN        0.074           NaN
# 13367         p003        1          e  NaN        0.076           NaN
# ...            ...      ...        ...  ...          ...           ...
# 550615        p098        2          s  NaN        0.089           NaN
# 553375        p099        1          e  NaN        0.113           NaN
# 556398        p099        2          s  NaN          0.1           NaN
# 559506        p100        1  Backspace  NaN        0.076           NaN
# 562569        p100        2          s  NaN        0.124           NaN
#
#         DU.key1.key2  UD.key1.key2  UU.key1.key2
# 2513             NaN           NaN            NaN
# ...

# %%
df=df.dropna(subset=["key2"])

# %%
df.isnull().sum()
# Out:
# participant      0
# session          0
# key1             0
# key2             0
# DU.key1.key1     0
# DD.key1.key2     0
# DU.key1.key2     0
# UD.key1.key2     0
# UU.key1.key2     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 562372 entries, 0 to 562568
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   participant    562372 non-null  object
#  1   session        562372 non-null  int64
#  2   key1           562372 non-null  object
#  3   key2           562372 non-null  object
#  4   DU.key1.key1   562372 non-null  object
#  5   DD.key1.key2   562372 non-null  float64
#  6   DU.key1.key2   562372 non-null  float64
#  7   UD.key1.key2   562372 non-null  float64
#  8   UU.key1.key2   562372 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 42.9+ MB
