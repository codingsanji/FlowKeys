# %%
import pandas as pd

fixed = pd.read_csv("../data/keystrokes/raw/fixed-text.csv")
free = pd.read_csv("../data/keystrokes/raw/free-text.csv")

free.head()
# Out:
# C:\Users\SombatlaTrucDeydeepy\AppData\Local\Temp\ipykernel_32220\1380128030.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   free = pd.read_csv("../data/keystrokes/raw/free-text.csv")
#   participant  session   key1   key2 DU.key1.key1  DD.key1.key2  DU.key1.key2  \
# 0        p001        1      W  Shift         0.15        -0.796         0.166
# 1        p001        1  Shift      e        0.962         1.148         1.255
# 2        p001        1      e  Space        0.107         0.172         0.252
# 3        p001        1  Space      b         0.08         0.200         0.280
# 4        p001        1      b      e         0.08         0.320         0.480
#
#    UD.key1.key2  UU.key1.key2   Unnamed: 9
# 0        -0.946          0.016         NaN
# 1         0.186          0.293         NaN
# 2         0.065          0.145         NaN
# 3         0.120          0.200         NaN
# ...

# %%
fixed.head()
# Out:
#   participant  session  repetition  DU.v.v  DD.v.p  DU.v.p  UD.v.p  UU.v.p  \
# 0        p001        1           1   0.129   1.917   1.804   2.046   1.933
# 1        p001        1           2   0.112   0.192   0.096   0.304   0.208
# 2        p001        1           3   0.088   0.253   0.182   0.341   0.270
# 3        p001        1           4   0.104   0.323   0.233   0.427   0.337
# 4        p001        1           5   0.107   0.188   0.100   0.295   0.207
#
#    DU.p.p  DD.p.w  ...  DU.r.k  UD.r.k  UU.r.k  DU.k.k.1  DD.k.b  DU.k.b  \
# 0   0.113   0.719  ...   1.289   1.509   1.423     0.086   0.450   0.352
# 1   0.096   0.448  ...   0.921   1.135   1.056     0.079   0.418   0.336
# 2   0.071   1.536  ...   1.066   1.271   1.194     0.077   0.448   0.352
# 3   0.090   0.912  ...   0.927   1.129   1.063     0.066   0.418   0.330
# 4   0.088   0.858  ...   1.237   1.423   1.344     0.079   0.457   0.369
#
#    UD.k.b  UU.k.b  DU.b.b  total time
# ...

# %%
fixed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19772 entries, 0 to 19771
# Data columns (total 50 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   participant  19772 non-null  object
#  1   session      19772 non-null  int64
#  2   repetition   19772 non-null  int64
#  3   DU.v.v       19772 non-null  float64
#  4   DD.v.p       19772 non-null  float64
#  5   DU.v.p       19772 non-null  float64
#  6   UD.v.p       19772 non-null  float64
#  7   UU.v.p       19772 non-null  float64
#  8   DU.p.p       19772 non-null  float64
#  9   DD.p.w       19772 non-null  float64
#  10  DU.p.w       19772 non-null  float64
#  11  UD.p.w       19772 non-null  float64
#  12  UU.p.w       19772 non-null  float64
#  13  DU.w.w       19772 non-null  float64
#  14  DD.w.j       19772 non-null  float64
#  15  DU.w.j       19772 non-null  float64
#  16  UD.w.j       19772 non-null  float64
#  17  UU.w.j       19772 non-null  float64
# ...

# %%
fixed.shape
# Out:
# (19772, 50)
